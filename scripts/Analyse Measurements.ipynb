# %%
import numpy as np
from bokeh_utility import *
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
def load_measurement(file_name):
    with open(file_name, 'rb') as f:
        adc_values = np.load(f)
        time_stamp = np.load(f)
    return adc_values, time_stamp

# %%
adc, time_stamp = load_measurement('data/NatrualMoundVibration_20210118-211633.npy')

# %%
plot_raw(y=adc, x=time_stamp, title='FirstTryJump_20210118-202505')
# Out:
#   <div class="bk-root" id="3e1498bf-c792-4ff8-afcb-0c9c40bc0acb" data-root-id="3118"></div>

# %%
plot_fft(adc[11370:13259])
# Out:
#   <div class="bk-root" id="2e7dacbc-f3d9-47be-a9e9-e41bae084983" data-root-id="3548"></div>

# %%
# 6.35 Hz, 81Hz
